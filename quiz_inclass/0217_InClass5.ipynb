# %%
import geopandas as gpd

# %%
def readfile(x,y):
    al = gpd.read_file(x)
    place = gpd.read_file(y).to_crs(al.crs)
    return al, place

# %%
al, place = readfile("C:/Users/thewe/OneDrive/Desktop/College/AES408/files/cb_2024_01_place_500k", "C:/Users/thewe/OneDrive/Desktop/College/AES408/files/ne_10m_populated_places")

# %%
al.head()
# Out:
#   STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID        NAME  \
# 0      01   32704  02403782  1600000US0132704  0132704  Haleyville
# 1      01   45472  02406131  1600000US0145472  0145472    McIntosh
# 2      01   53784  02406982  1600000US0153784  0153784     Newbern
# 3      01   78204  02405634  1600000US0178204  0178204      Valley
# 4      01   02836  02405172  1600000US0102836  0102836     Ashford
#
#           NAMELSAD STUSPS STATE_NAME LSAD     ALAND  AWATER  \
# 0  Haleyville city     AL    Alabama   25  21713018  130983
# 1    McIntosh town     AL    Alabama   43   2579767       0
# 2     Newbern town     AL    Alabama   43   3010370    6872
# 3      Valley city     AL    Alabama   25  33384157       0
# 4     Ashford city     AL    Alabama   25  16064130   56699
#
#                                             geometry
# 0  MULTIPOLYGON (((-87.60417 34.24614, -87.60201 ...
# 1  POLYGON ((-88.03726 31.27171, -88.03112 31.271...
# ...

# %%
place.head()
# Out:
#    SCALERANK  NATSCALE  LABELRANK       FEATURECLA                    NAME  \
# 0         10         1        8.0  Admin-1 capital  Colonia del Sacramento
# 1         10         1        8.0  Admin-1 capital                Trinidad
# 2         10         1        8.0  Admin-1 capital             Fray Bentos
# 3         10         1        8.0  Admin-1 capital               Canelones
# 4         10         1        8.0  Admin-1 capital                 Florida
#
#   NAMEPAR NAMEALT               NAMEASCII  ADM0CAP CAPIN  ...  FCLASS_ID  \
# 0     NaN     NaN  Colonia del Sacramento        0   NaN  ...        NaN
# 1     NaN     NaN                Trinidad        0   NaN  ...        NaN
# 2     NaN     NaN             Fray Bentos        0   NaN  ...        NaN
# 3     NaN     NaN               Canelones        0   NaN  ...        NaN
# 4     NaN     NaN                 Florida        0   NaN  ...        NaN
#
#    FCLASS_PL FCLASS_GR FCLASS_IT FCLASS_NL FCLASS_SE FCLASS_BD FCLASS_UA  \
# ...

# %%
al_place = gpd.sjoin(al, place)

# %%
al_place
# Out:
#     STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID   NAME_left  \
# 16       01   50000  02404278  1600000US0150000  0150000      Mobile
# 75       01   51000  02404289  1600000US0151000  0151000  Montgomery
# 95       01   26896  02403619  1600000US0126896  0126896    Florence
# 99       01   28696  02403673  1600000US0128696  0128696     Gadsden
# 133      01   21184  02404238  1600000US0121184  0121184      Dothan
# 173      01   07000  02403868  1600000US0107000  0107000  Birmingham
# 196      01   69120  02405441  1600000US0169120  0169120       Selma
# 247      01   03076  02403132  1600000US0103076  0103076      Auburn
# 382      01   24184  02403567  1600000US0124184  0124184  Enterprise
# 414      01   77256  02405614  1600000US0177256  0177256  Tuscaloosa
# 516      01   37000  02404746  1600000US0137000  0137000  Huntsville
#
#             NAMELSAD STUSPS STATE_NAME LSAD  ...  FCLASS_TR  FCLASS_ID  \
# ...
