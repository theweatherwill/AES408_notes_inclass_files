# %%
import geopandas as gpd
import pandas as pd

# %%
madison_roads = gpd.read_file("C:/Users/thewe/OneDrive/Desktop/College/AES408/files/tl_2025_01089_roads.zip")

# %%
madison_roads.plot()
# Out:
# <Axes: >

# %%
madison_roads
# Out:
#              LINEARID              FULLNAME RTTYP  MTFCC  \
# 0         11074849208        N Hi Lo Cir NE     M  S1400
# 1         11074854543     N Edgemont Cir NW     M  S1400
# 2         11074848302          N Park Dr NW     M  S1400
# 3       1108296578028  N Mossy Creek Cir NW     M  S1400
# 4         11074855276      N Plymouth Rd NW     M  S1400
# ...               ...                   ...   ...    ...
# 22709     11074851465             Oregon Dr     M  S1400
# 22710  11019626775580      Erskin Parcus Dr     M  S1400
# 22711     11074932202                   NaN   NaN  S1400
# 22712     11074920951                   NaN   NaN  S1400
# 22713  11016955668371         State Line Rd     M  S1400
#
#                                                 geometry
# 0      LINESTRING (-86.56594 34.77288, -86.56594 34.7...
# 1      LINESTRING (-86.57588 34.76996, -86.57588 34.7...
# 2      LINESTRING (-86.58899 34.75792, -86.58862 34.7...
# ...

# %%
madison_roads_reix = madison_roads.set_index("FULLNAME")

# %%
madison_roads_reix.groupby("FULLNAME").count().sort_values("LINEARID",ascending=False)
# Out:
#                      LINEARID  RTTYP  MTFCC  geometry
# FULLNAME
# US Hwy 431                 30     30     30        30
# State Rte 1                30     30     30        30
# Nature Walk Blvd SW        27     27     27        27
# US Hwy 72                  21     21     21        21
# State Rte 2                21     21     21        21
# ...                       ...    ...    ...       ...
# Zephyr Cir SE               1      1      1         1
# Avonshire Ct                1      1      1         1
# Avonwood Ln SE              1      1      1         1
# Zimfran Ave SE              1      1      1         1
# 2nd Ave NW                  1      1      1         1
#
# [7348 rows x 4 columns]
