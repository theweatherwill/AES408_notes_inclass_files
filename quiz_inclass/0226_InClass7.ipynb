# %%
import numpy as np
import rioxarray as rio

# %%
rio.open_rasterio(r"C:\Users\thewe\OneDrive\Desktop\College\AES408\files\N34W087.SRTMGL1.hgt")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\thewe\OneDrive\Desktop\College\AES408\.pixi\envs\default\Lib\site-packages\xarray\backends\file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File c:\Users\thewe\OneDrive\Desktop\College\AES408\.pixi\envs\default\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x000001C417216AE0>, ('C:/Users/thewe/Downloads/N34W087.SRTMGL1.hgt',), 'r', (('sharing', False),), '8a7f777b-e6b1-436c-9385-58393822353a']
#
# During handling of the above exception, another exception occurred:
#
# ...
