# %%
import numpy as np
import rioxarray as rio

# %%
hsv_data = rio.open_rasterio(r"C:\temp\N34W087.hgt")

# %%
hsv_data
# Out:
# <xarray.DataArray (band: 1, y: 3601, x: 3601)> Size: 26MB
# array([[[191, 192, ..., 464, 459],
#         [191, 193, ..., 467, 461],
#         ...,
#         [182, 179, ..., 154, 154],
#         [183, 180, ..., 154, 154]]], shape=(1, 3601, 3601), dtype=int16)
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 29kB 35.0 35.0 35.0 35.0 ... 34.0 34.0 34.0 34.0
#   * x            (x) float64 29kB -87.0 -87.0 -87.0 -87.0 ... -86.0 -86.0 -86.0
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Point
#     _FillValue:     -32768
#     scale_factor:   1.0
#     add_offset:     0.0
#     units:          m

# %%
hsv_data_reproj = hsv_data.rio.reproject("EPSG:32616")

# %%
hsv_data_reproj
# Out:
# <xarray.DataArray (band: 1, y: 3939, x: 3267)> Size: 26MB
# array([[[-32768, -32768, -32768, ..., -32768, -32768, -32768],
#         [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#         [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#         ...,
#         [   181,    179,    178, ..., -32768, -32768, -32768],
#         [   182,    179,    177, ..., -32768, -32768, -32768],
#         [   183,    180,    180, ..., -32768, -32768, -32768]]],
#       shape=(1, 3939, 3267), dtype=int16)
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 32kB 3.874e+06 3.873e+06 ... 3.762e+06 3.762e+06
#   * x            (x) float64 26kB 5e+05 5e+05 5.001e+05 ... 5.923e+05 5.924e+05
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Point
#     scale_factor:   1.0
#     add_offset:     0.0
#     units:          m
#     _FillValue:     -32768

# %%
hsv_data_reproj.rio.resolution()
# Out:
# (28.276528429553007, -28.276528429553007)

# %%
hsv_data_reproj.plot()

# %%
above500 = (hsv_data_reproj > 500).sum()
above500
# Out:
# <xarray.DataArray ()> Size: 8B
# array(214742)
# Coordinates:
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Point
#     scale_factor:   1.0
#     add_offset:     0.0
#     units:          m
#     _FillValue:     -32768

# %%
total_pix_bypixel = 3939 * 3267 * 1
total_pix_bypixel
# Out:
# 12868713
